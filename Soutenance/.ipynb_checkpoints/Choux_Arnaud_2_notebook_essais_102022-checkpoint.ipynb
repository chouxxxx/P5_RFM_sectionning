# %% [markdown]
# Projet 5 - Segmentez des clients d'un site e-commerce - Prediction 1
# # 1. Initialisation

# %% [markdown]
# >>-
# ## 11. Package imports

# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20, "display.max_columns", None)
import matplotlib.pyplot as plt
import seaborn as sns
#import re
import my
#import math
#import timeit
import time
#from scipy import interpolate
#import geopandas
#import os
#import sys
from IPython.display import clear_output
import warnings

# %%
from sklearn import cluster
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.metrics import silhouette_samples, silhouette_score

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>ATTENTION !</b> Tous les tests que j'ai effectués avec RobustScaler donnent une classification KMeans défaillante, qui ne tient pas du tout compte des valeurs de F. StandardScaler donne des résultats bien plus cohérents ici.</div>

# %% [markdown]
# >>-
# ## 12. Data imports

# %%
df = my.read_csv('dfs_1.csv')
dfrs = my.read_csv('dfs_rs_min.csv')
#dflog = my.read_csv('dfs_log.csv')
dfllll = my.read_csv('dfs_loglogloglog.csv')
# Out:
# Y'avait pas de colonne 'Unnamed: 0'
# Y'avait pas de colonne 'Unnamed: 0'
# Y'avait pas de colonne 'Unnamed: 0'

# %% [markdown]
# >>-
# ## 13. Initialisation des classifications

# %%
def init_classif_in(df=df, cols_num=["R","F","M"], ns=0):
    """
    Création de X à partir d'un dataset de RFM(S), éventuellement subsampled.
    """
    if "S" in cols_num:
        X = df.rename(columns={"rs": "S"})[cols_num]
    else:
        X = df[cols_num]

    if ns:
#        print(X.shape, sum(X.F == 1))
        pct = (1-sum(X.F == 1)/X.shape[0])*100
        print("Il y a {a:.1f}% de clients ayant effectué plus d'un achat "
              "dans le dataset avant subsampling.".format(a=pct))
        X = X.sample(n=ns, weights=None, random_state=1)
                     #frac=.1, weights="F", random_state=1)
#        print(X.shape, sum(X.F == 1))
        pct = (1-sum(X.F == 1)/X.shape[0])*100
        print("Il y a {a:.1f}% de clients ayant effectué plus d'un achat "
              "dans la subsample sélectionnée.".format(a=pct))

    return X

# %%
def init_classif(df=df, cols_num=["R","F","M"], ns=0):
    """
    Création de X scalé avec son propre StandardScaler.
    """
    X = init_classif_in(df, cols_num, ns)
    scaler = StandardScaler()
    X[cols_num] = scaler.fit_transform(X[cols_num])
    return X

# %% [markdown]
# >-
# # 2. Premiers tests de classification avec DBSCAN

# %% [markdown]
# >>-
# ## 21. Dataset linéaire

# %%
X = init_classif(ns=3000)
# Out:
# Il y a 2.9% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 3.0% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.

# %%
for eps in np.logspace(0,1,3):
    for mins in [1,2,3]:
        model = cluster.DBSCAN(eps=eps, min_samples=mins)
        model = model.fit(X)
        print("eps:", eps,
              ", min_samples:", mins,
              ", # labels:", len(set(model.labels_))
             )
# Out:
# eps: 1.0 , min_samples: 1 , # labels: 16
# eps: 1.0 , min_samples: 2 , # labels: 9
# eps: 1.0 , min_samples: 3 , # labels: 7
# eps: 3.1622776601683795 , min_samples: 1 , # labels: 4
# eps: 3.1622776601683795 , min_samples: 2 , # labels: 4
# eps: 3.1622776601683795 , min_samples: 3 , # labels: 4
# eps: 10.0 , min_samples: 1 , # labels: 1
# eps: 10.0 , min_samples: 2 , # labels: 1
# eps: 10.0 , min_samples: 3 , # labels: 1

# %% [markdown]
# (eps=3, min_samples=1) semble convenir.

# %%
# %%script echo
# model = cluster.DBSCAN(eps=3, min_samples=1)
# model = model.fit(X)
# y_pred = model.predict(X)
# set(model.labels_)
# Out:
# Couldn't find program: 'echo'

# %% [markdown]
# >>-
# ## 22. Dataset avec review_score

# %%
X = init_classif(df=dfrs, cols_num=["R","F","M","S"], ns=3000)
# Out:
# Il y a 2.8% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 2.8% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.

# %%
for eps in np.logspace(0,1,3):
    for mins in [1,2,3]:
        model = cluster.DBSCAN(eps=eps, min_samples=mins)
        model = model.fit(X)
        print("eps:", eps,
              ", min_samples:", mins,
              ", # labels:", len(set(model.labels_))
             )
# Out:
# eps: 1.0 , min_samples: 1 , # labels: 22
# eps: 1.0 , min_samples: 2 , # labels: 10
# eps: 1.0 , min_samples: 3 , # labels: 6
# eps: 3.1622776601683795 , min_samples: 1 , # labels: 5
# eps: 3.1622776601683795 , min_samples: 2 , # labels: 4
# eps: 3.1622776601683795 , min_samples: 3 , # labels: 4
# eps: 10.0 , min_samples: 1 , # labels: 1
# eps: 10.0 , min_samples: 2 , # labels: 1
# eps: 10.0 , min_samples: 3 , # labels: 1

# %% [markdown]
# >>-
# ## 23. Test avec min_samples grand

# %%
for eps in np.logspace(0,1,3):
    for mins in [10,30,100,300]:
        model = cluster.DBSCAN(eps=eps, min_samples=mins)
        model = model.fit(X)
        print("eps:", eps,
              ", min_samples:", mins,
              ", # labels:", len(set(model.labels_)))
# Out:
# eps: 1.0 , min_samples: 10 , # labels: 3
# eps: 1.0 , min_samples: 30 , # labels: 2
# eps: 1.0 , min_samples: 100 , # labels: 2
# eps: 1.0 , min_samples: 300 , # labels: 2
# eps: 3.1622776601683795 , min_samples: 10 , # labels: 3
# eps: 3.1622776601683795 , min_samples: 30 , # labels: 3
# eps: 3.1622776601683795 , min_samples: 100 , # labels: 2
# eps: 3.1622776601683795 , min_samples: 300 , # labels: 2
# eps: 10.0 , min_samples: 10 , # labels: 1
# eps: 10.0 , min_samples: 30 , # labels: 1
# eps: 10.0 , min_samples: 100 , # labels: 1
# eps: 10.0 , min_samples: 300 , # labels: 1

# %% [markdown]
# >>-
# ## 24. Dataset loglogloglog

# %%
X = init_classif(df=dfllll, ns=3000)
# Out:
# Il y a 2.9% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 3.0% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.

# %%
for eps in np.logspace(0,1,3):
    for mins in [1,2,3]:
        model = cluster.DBSCAN(eps=eps, min_samples=mins)
        model = model.fit(X)
        print("eps:", eps,
              ", min_samples:", mins,
              ", # labels:", len(set(model.labels_))
             )
# Out:
# eps: 1.0 , min_samples: 1 , # labels: 6
# eps: 1.0 , min_samples: 2 , # labels: 6
# eps: 1.0 , min_samples: 3 , # labels: 4
# eps: 3.1622776601683795 , min_samples: 1 , # labels: 2
# eps: 3.1622776601683795 , min_samples: 2 , # labels: 2
# eps: 3.1622776601683795 , min_samples: 3 , # labels: 2
# eps: 10.0 , min_samples: 1 , # labels: 1
# eps: 10.0 , min_samples: 2 , # labels: 1
# eps: 10.0 , min_samples: 3 , # labels: 1

# %% [markdown]
# >>-
# ## 23. Algo OPTICS

# %%
X = init_classif(ns=3000)
# Out:
# Il y a 2.9% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 3.0% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.

# %%
for mins in [.5,1,2,3]:
    model = cluster.OPTICS(min_samples=mins)
    model = model.fit(X)
    print("min_samples:", mins,
          ", # labels:", len(set(model.labels_)))
# Out:
# min_samples: 0.5 , # labels: 1
# min_samples: 1 , # labels: 1
# min_samples: 2 , # labels: 890
# min_samples: 3 , # labels: 439

# %% [markdown]
# OPTICS avec la cluster_method "xi" ne convient pas.

# %% [markdown]
# >-
# # 3. Recherche du nombre de clusters idéal pour KMeans

# %% [markdown]
# >>-
# ## 31. Dataset linéaire

# %%
X = init_classif(ns=10000)

wcss = []
range_n_clusters = range(2,7)

print("progress: ", end="")
for loop_step, n_clusters in enumerate(range_n_clusters):
    print(100*loop_step/len(range_n_clusters), "% ", end="--> ")

    y_lower = 10
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
    fig.set_size_inches(10, 3)
    plt.subplots_adjust(
        left=0.01, right=0.99, bottom=0.001, top=0.8, wspace=0.34, hspace=0.35
    )
    ax1.set_xlim([-0.07, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1)*10])
    subp_dic = {
        'RF'   : [ax2, X.R, 0, X.F, 1],
        'RM'   : [ax3, X.R, 0, X.M, 2],
        'FM'   : [ax4, X.F, 1, X.M, 2],
    }

    # We set the seed for reproducibility.
    clusterer = cluster.KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)
    centers = clusterer.cluster_centers_
    # Record wcss for the elbow graph.
    wcss.append(clusterer.inertia_)

    silhouette_avg = silhouette_score(X, cluster_labels)
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    for i in range(n_clusters):
        ith_cluster_silhouette_values = sample_silhouette_values[
            cluster_labels == i
        ]
        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            cmap="tab10",
#            cmap=sns.color_palette("bright", n_colors=n_clusters, as_cmap=True),
#            color=sns.color_palette("bright", n_colors=n_clusters),
            alpha=0.7,
        )
        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        y_lower = y_upper + 10

    ax1.set_title("Silhouettes (avg={a:1.2f})".format(a=silhouette_avg))
    ax1.set_xlabel("Silhouette coefficients")
    ax1.set_ylabel("Cluster label")
    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    for sd in subp_dic.values():
        sd[0].scatter(
            sd[1],
            sd[3],
            marker=".",
            s=30,
            lw=0,
            alpha=0.7,
            c=pd.Series(cluster_labels).map(dict(zip(np.unique(cluster_labels),
                                          sns.color_palette(
#                                              "bright",
                                              "tab10",
                                              n_colors=n_clusters,
                                          )))),
            edgecolor="k",
        )

        sd[0].scatter(
            centers[:, sd[2]],
            centers[:, sd[4]],
            marker="o",
            c="white",
            alpha=1,
            s=200,
            edgecolor="k",
        )

        for i, c in enumerate(centers):
            sd[0].scatter(
                c[sd[2]],
                c[sd[4]],
                marker="$%d$" % i,
                alpha=1,
                s=50,
                edgecolor="k",
            )

        sd[0].set_title(sd[1].name + "-" + sd[3].name + " projection")
        sd[0].set_xlabel(sd[1].name)
        sd[0].set_ylabel(sd[3].name)

    plt.suptitle(
        "KMeans Silhouette analysis for n_clusters = %d"
        % n_clusters,
        fontsize=11,
        fontweight="bold",
    )

    plt.savefig("KMeans_silhouette_RFM_" + str(n_clusters) + "clusters.png",
                bbox_inches="tight")

print(100, "%")
plt.show()

fig = plt.figure(figsize=(4, 4))
plt.plot(range_n_clusters, wcss)
plt.title("Méthode du coude")
plt.xlabel("n_clusters")
plt.ylabel("Some des carrés intra-cluster (WCSS)")
plt.savefig("KMeans_elbow_RFM_.png",
            bbox_inches="tight")
# Out:
# Il y a 2.9% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 2.7% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.
# progress: 0.0 % --> 20.0 % --> 40.0 % --> 60.0 % --> 80.0 % --> 100 %

# %% [markdown]
# La méthode du coude montre un nombre de clusters optimal de 4.
# L'analyse de silhouette donne également un nombre de clusters optimal de 4.
# Les clusters obtenus sont:
# - petit F, petit M, R_scaled > 0 (beaucoup de données)
# - petit F, petit M, R_scaled < 0 (beaucoup de données)
# - grand F, (petit M ?) (peu de données car comportement de clients plus rare)
# - (petit F ?), grand M (peu de données car comportement de clients plus rare)
# Le 5è cluster vient séparer les deux larges clusters en 3 de petit F et petit M.
# Le 6è cluster vient séparer le petit cluster de grand M en un cluster de grand M
# et un cluster de très grand M.

# %% [markdown]
# >>-
# ## 31. Dataset avec review_score

# %%
X = init_classif(df=dfrs, cols_num=["R","F","M","S"], ns=3000)

wcss = []
range_n_clusters = range(2,7)

print("progress: ", end="")
for loop_step, n_clusters in enumerate(range_n_clusters):
    print(100*loop_step/len(range_n_clusters), "% ", end="--> ")

    y_lower = 10
    fig, axs = plt.subplots(2, 4)
    fig.set_size_inches(10, 6)
    plt.subplots_adjust(
        left=0.01, right=0.99, bottom=0.001, top=0.9, wspace=0.4, hspace=0.35
    )
    axs[0,0].set_xlim([-0.07, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    axs[0,0].set_ylim([0, len(X) + (n_clusters + 1)*10])
    subp_dic = {
#        "RF"   : [axs[0,1], X.R, 0, X.F, 1, "Recency", "Frequency"],
        "RF"   : [axs[0,1], X.R, 0, X.F, 1],
        "RM"   : [axs[0,2], X.R, 0, X.M, 2],
        "FM"   : [axs[0,3], X.F, 1, X.M, 2],
        "RS"   : [axs[1,1], X.R, 0, X.S, 3],
        "FS"   : [axs[1,2], X.F, 1, X.S, 3],
        "MS"   : [axs[1,3], X.M, 2, X.S, 3],
    }

    # We set the seed for reproducibility.
    clusterer = cluster.KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)
    centers = clusterer.cluster_centers_
    # Record wcss for the elbow graph.
    wcss.append(clusterer.inertia_)

    silhouette_avg = silhouette_score(X, cluster_labels)
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    for i in range(n_clusters):
        ith_cluster_silhouette_values = sample_silhouette_values[
            cluster_labels == i
        ]
        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        axs[0,0].fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            cmap="tab10",
#            cmap=sns.color_palette("bright", n_colors=n_clusters, as_cmap=True),
#            color=sns.color_palette("bright", n_colors=n_clusters),
            alpha=0.7,
        )
        # Label the silhouette plots with their cluster numbers at the middle
        axs[0,0].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        y_lower = y_upper + 10

    axs[0,0].set_title("Silhouettes (avg={a:1.2f})".format(a=silhouette_avg))
    axs[0,0].set_xlabel("Silhouette coefficients")
    axs[0,0].set_ylabel("Cluster label")
    axs[0,0].set_yticks([])  # Clear the yaxis labels / ticks
    axs[0,0].set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    axs[0,0].axvline(x=silhouette_avg, color="red", linestyle="--")

    for sd in subp_dic.values():
        sd[0].scatter(
            sd[1],
            sd[3],
            marker=".",
            s=30,
            lw=0,
            alpha=0.7,
            c=pd.Series(cluster_labels).map(dict(zip(np.unique(cluster_labels),
                                          sns.color_palette(
#                                              "bright",
                                              "tab10",
                                              n_colors=n_clusters,
                                          )))),
            edgecolor="k",
        )

        sd[0].scatter(
            centers[:, sd[2]],
            centers[:, sd[4]],
            marker="o",
            c="white",
            alpha=1,
            s=200,
            edgecolor="k",
        )

        for i, c in enumerate(centers):
            sd[0].scatter(
                c[sd[2]],
                c[sd[4]],
                marker="$%d$" % i,
                alpha=1,
                s=50,
                edgecolor="k",
            )

        sd[0].set_title(sd[1].name + "-" + sd[3].name + " projection")
        sd[0].set_xlabel(sd[1].name)
        sd[0].set_ylabel(sd[3].name)

    plt.suptitle(
        "KMeans Silhouette analysis for n_clusters = %d"
        % n_clusters,
        fontsize=11,
        fontweight="bold",
    )

    axs[1,0].axis('off')

    plt.savefig("KMeans_silhouette_RFMS_" + str(n_clusters) + "clusters.png",
                bbox_inches="tight")

print(100, "%")
plt.show()

fig = plt.figure(figsize=(4, 4))
plt.plot(range_n_clusters, wcss)
plt.title("Méthode du coude")
plt.xlabel("n_clusters")
plt.ylabel("Some des carrés intra-cluster (WCSS)")
plt.savefig("KMeans_elbow_RFMS_.png",
            bbox_inches="tight")
# Out:
# Il y a 2.8% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 2.8% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.
# progress: 0.0 % --> 20.0 % --> 40.0 % --> 60.0 % --> 80.0 % --> 100 %

# %% [markdown]
# >-
# # 4. Stabilité du KMeans à 5 clusters avec review_score

# %%
scaler = StandardScaler()
cols_num=["R","F","M","S"]
X = init_classif_in(df=dfrs, cols_num=cols_num)
Xns = X.copy()
X[cols_num] = scaler.fit_transform(X[cols_num])

# %%
ls_y_pred = []
for i in range(5):
    model = cluster.KMeans(n_clusters=5, init="random")
    y_pred = model.fit_predict(X)
    ls_y_pred.append(y_pred)
    Xns["label"] = pd.Series(y_pred)
#    print(Xns.groupby("label").R.count())
#    print(Xns.groupby("label").mean())
#    print(Xns.groupby("label").std())
df_stats_ccl = pd.DataFrame(Xns.groupby("label").mean())
df_stats_ccl.loc[:,"count"] = Xns.groupby("label").R.count()
df_stats_ccl
# Out:
#                   R         F            M         S  count
# label
# 0      3.822608e+07  1.000000   134.910418  4.631561  31761
# 1      2.285980e+07  2.114200   308.853573  3.723892   2662
# 2      2.480048e+07  1.019598  1283.273092  3.948555   2041
# 3      1.479985e+07  1.000000   133.670017  4.668581  42128
# 4      2.529207e+07  1.000000   153.343989  1.588849  16787

# %% [markdown]
# Le KMeans trouve les clusters suivants:
# - S bas (1.6/5), RFM moyens. -> client déçu. -> Excuses et bon d'achat.
# - S haut, achat récent, FM moyens. -> nouveau client -> pas d'action.
# - S haut, achat daté, FM moyens. -> client satisfait mais perdu -> news/discount.
# - M haut, RFS moyens. -> un seul gros achat -> news.
# - F haut, RMS moyens. -> client fréquent -> proposition d'abonnement VIP.

# %%
from sklearn.metrics import adjusted_rand_score

# %%
ARIs = []
for i, j in enumerate(ls_y_pred):
    for m, n in enumerate(ls_y_pred):
        ARIi = adjusted_rand_score(j, n)
#        print(ARIi)
        ARIs.append(ARIi)
print(pd.Series(ARIs).mean(), pd.Series(ARIs).std())
# Out:
# 0.9998779504580605 0.00015252133979941612

# %% [markdown]
# Excellent résultat ! Le KMeans à 5 clusters trouve toujours les mêmes clusters
# malgré le init="random".

# %%
sns.scatterplot(X.R, X.M, y_pred)
# Out:
# C:\Users\achou\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='R', ylabel='M'>

# %%
scaler = StandardScaler()
cols_num=["R","F","M","S"]
X = init_classif_in(df=dfrs, cols_num=cols_num)
Xns = X.copy()
X[cols_num] = scaler.fit_transform(X[cols_num])

# %%
import sklearn
from sklearn.model_selection import GridSearchCV

def cv_silhouette_scorer(estimator, X):
    """
    Setup du scorer pour le GridSearchCV.
    Je choisis ici le silhouette_score comme scorer.
    """
    estimator.fit(X)
    cluster_labels = estimator.labels_
    num_labels = len(set(cluster_labels))
    num_samples = len(X.index)
    if num_labels == 1 or num_labels == num_samples:
        return -1
    else:
        return silhouette_score(X, cluster_labels)

param_dict = {
    "n_clusters": [5],
#    "KMeans__n_clusters": 5,
    "init": ["random", "k-means++"],
    "n_init": [10],
    "max_iter": [300],
    "tol": [1e-4],
    "verbose": [1],
    "random_state": [None],
    "copy_x": [True],
    "algorithm": ["lloyd", "elkan"],
}

cv = [(slice(None), slice(None))]
gs = GridSearchCV(estimator=sklearn.cluster.KMeans(), param_grid=param_dict,
                  scoring=cv_silhouette_scorer, cv=cv, n_jobs=-1)
gs.fit(X)
# Out:
# C:\Users\achou\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 4.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\achou\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 678, in _fit_and_score
#     estimator.fit(X_train, **fit_params)
#   File "C:\Users\achou\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py", line 1146, in fit
#     self._check_params(X)
#   File "C:\Users\achou\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py", line 956, in _check_params
#     raise ValueError(
# ValueError: Algorithm must be 'auto', 'full' or 'elkan', got lloyd instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\achou\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.41750182 0.41743997]
#   warnings.warn(
# Initialization complete
# Iteration 0, inertia 328280.2000696122
# Iteration 1, inertia 246753.90622113415
# Iteration 2, inertia 216043.14009036188
# Iteration 3, inertia 177343.69862282454
# Iteration 4, inertia 168898.25977425938
# Iteration 5, inertia 165485.85325378747
# Iteration 6, inertia 163595.65212070176
# Iteration 7, inertia 162246.32602282197
# Iteration 8, inertia 161175.4305438821
# Iteration 9, inertia 160245.84390292715
# Iteration 10, inertia 159726.83097887633
# Iteration 11, inertia 159533.40612913668
# Iteration 12, inertia 159435.71402365356
# Iteration 13, inertia 159365.4577760981
# Iteration 14, inertia 159325.72245197056
# Iteration 15, inertia 159308.47071218304
# Iteration 16, inertia 159301.05032755836
# Converged at iteration 16: center shift 5.6610219150824375e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 390614.1378955625
# Iteration 1, inertia 257994.19540801772
# Iteration 2, inertia 215453.18123789039
# Iteration 3, inertia 188808.00139081918
# Iteration 4, inertia 176012.54860459283
# Iteration 5, inertia 170384.02757992636
# Iteration 6, inertia 167541.1018590086
# Iteration 7, inertia 165980.52298289278
# Iteration 8, inertia 164654.55401465
# Iteration 9, inertia 163439.6663471538
# Iteration 10, inertia 162168.17310483425
# Iteration 11, inertia 160943.82997023134
# Iteration 12, inertia 158361.47840717313
# Iteration 13, inertia 153614.9250763002
# Iteration 14, inertia 143514.6507316473
# Iteration 15, inertia 131410.6709544477
# Iteration 16, inertia 129123.75153308574
# Iteration 17, inertia 128602.25848329744
# Iteration 18, inertia 128380.95605997
# Iteration 19, inertia 128287.56017287144
# Iteration 20, inertia 128247.49675173833
# Iteration 21, inertia 128226.20334676263
# Iteration 22, inertia 128217.80170701043
# Iteration 23, inertia 128213.65196578484
# Iteration 24, inertia 128212.06649345312
# Iteration 25, inertia 128211.48698229383
# Iteration 26, inertia 128210.90785978807
# Iteration 27, inertia 128210.45563302461
# Converged at iteration 27: center shift 3.835572499664642e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 231915.87472588892
# Iteration 1, inertia 191384.2138483966
# Iteration 2, inertia 186636.31687947115
# Iteration 3, inertia 184864.04454792774
# Iteration 4, inertia 183444.50170751638
# Iteration 5, inertia 178950.95272568832
# Iteration 6, inertia 167522.393226458
# Iteration 7, inertia 164738.34402530224
# Iteration 8, inertia 163297.60449252924
# Iteration 9, inertia 162107.99604434823
# Iteration 10, inertia 161144.2847584052
# Iteration 11, inertia 160227.98261213687
# Iteration 12, inertia 159647.7647162287
# Iteration 13, inertia 159434.63923752896
# Iteration 14, inertia 159359.4088213279
# Iteration 15, inertia 159318.77865877718
# Iteration 16, inertia 159303.73065165203
# Iteration 17, inertia 159298.22005885845
# Converged at iteration 17: center shift 3.986275256354485e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 292504.68508019566
# Iteration 1, inertia 240867.37052807354
# Iteration 2, inertia 202204.7944440048
# Iteration 3, inertia 180694.25825342507
# Iteration 4, inertia 170534.23410900214
# Iteration 5, inertia 166347.55844158673
# Iteration 6, inertia 164291.87503177804
# Iteration 7, inertia 162957.09871152174
# Iteration 8, inertia 161802.4453067326
# Iteration 9, inertia 160669.19922000053
# Iteration 10, inertia 159717.79025280772
# Iteration 11, inertia 159386.2423696357
# Iteration 12, inertia 159306.53730047925
# Iteration 13, inertia 159285.217918825
# Iteration 14, inertia 159280.8238908924
# Converged at iteration 14: center shift 2.0612130076640934e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 265137.73864034255
# Iteration 1, inertia 211654.38632772895
# Iteration 2, inertia 191777.58325580627
# Iteration 3, inertia 184877.04289596828
# Iteration 4, inertia 175819.95261354334
# Iteration 5, inertia 167995.49673154065
# Iteration 6, inertia 165175.56248457814
# Iteration 7, inertia 163625.2262646093
# Iteration 8, inertia 162337.47633157668
# Iteration 9, inertia 161240.91234209354
# Iteration 10, inertia 160199.30685871508
# Iteration 11, inertia 159563.62474963683
# Iteration 12, inertia 159349.70908839128
# Iteration 13, inertia 159296.35364552448
# Iteration 14, inertia 159283.11457969423
# Iteration 15, inertia 159280.44527740864
# Converged at iteration 15: center shift 1.625760519504383e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 302447.205426719
# Iteration 1, inertia 241598.70194165898
# Iteration 2, inertia 213926.34770733735
# Iteration 3, inertia 191137.2248771799
# Iteration 4, inertia 153575.95565006076
# Iteration 5, inertia 129381.1213341231
# Iteration 6, inertia 128747.66136907185
# Iteration 7, inertia 128470.3481273474
# Iteration 8, inertia 128335.79089419657
# Iteration 9, inertia 128271.26242149089
# Iteration 10, inertia 128238.28772155214
# Iteration 11, inertia 128221.62563244866
# Iteration 12, inertia 128216.43490471516
# Iteration 13, inertia 128213.05451622364
# Iteration 14, inertia 128211.97076948559
# Iteration 15, inertia 128211.43213648726
# Iteration 16, inertia 128210.90711169665
# Iteration 17, inertia 128210.45482161269
# Converged at iteration 17: center shift 3.834105027843453e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 211476.71018259923
# Iteration 1, inertia 137366.9092789351
# Iteration 2, inertia 131388.9117279922
# Iteration 3, inertia 129375.59270285105
# Iteration 4, inertia 128671.93242402904
# Iteration 5, inertia 128394.82379702241
# Iteration 6, inertia 128290.78095539619
# Iteration 7, inertia 128247.79784612937
# Iteration 8, inertia 128225.81254985185
# Iteration 9, inertia 128217.66325796192
# Iteration 10, inertia 128213.65793324586
# Iteration 11, inertia 128212.06565015814
# Iteration 12, inertia 128211.48576581941
# Iteration 13, inertia 128210.90711169665
# Iteration 14, inertia 128210.45482161269
# Converged at iteration 14: center shift 3.8341050278414615e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 297452.4104054037
# Iteration 1, inertia 220227.63696685623
# Iteration 2, inertia 200166.34093012815
# Iteration 3, inertia 185261.35307332914
# Iteration 4, inertia 174140.9353056228
# Iteration 5, inertia 168583.1213879281
# Iteration 6, inertia 166253.282092825
# Iteration 7, inertia 164898.0575113727
# Iteration 8, inertia 163784.06555141398
# Iteration 9, inertia 162854.20978062673
# Iteration 10, inertia 162048.91126471607
# Iteration 11, inertia 161665.53398663423
# Iteration 12, inertia 161561.6228511607
# Iteration 13, inertia 161543.89022491613
# Iteration 14, inertia 161540.40689229002
# Converged at iteration 14: center shift 4.367952222502536e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 258086.78034245633
# Iteration 1, inertia 227796.47062149047
# Iteration 2, inertia 220158.98676602877
# Iteration 3, inertia 207191.18828526308
# Iteration 4, inertia 184750.1128888587
# Iteration 5, inertia 174429.27850625772
# Iteration 6, inertia 169910.2037149273
# Iteration 7, inertia 167339.67426619335
# Iteration 8, inertia 165872.61876592864
# Iteration 9, inertia 164635.626185869
# Iteration 10, inertia 163568.26159486172
# Iteration 11, inertia 162641.91259389406
# Iteration 12, inertia 162140.76023545285
# Iteration 13, inertia 161934.90876635961
# Iteration 14, inertia 161813.72540804528
# Iteration 15, inertia 161677.24103136064
# Iteration 16, inertia 161529.23533266044
# Iteration 17, inertia 161360.12085636376
# Iteration 18, inertia 161136.89364837375
# Iteration 19, inertia 160845.12260733455
# Iteration 20, inertia 160436.50079505148
# Iteration 21, inertia 159399.76236024316
# Iteration 22, inertia 155966.9484403294
# Iteration 23, inertia 143369.31461902562
# Iteration 24, inertia 131190.41736202364
# Iteration 25, inertia 129144.26983416392
# Iteration 26, inertia 128645.20398018644
# Iteration 27, inertia 128418.4763590588
# Iteration 28, inertia 128309.0849758841
# Iteration 29, inertia 128257.50921084057
# Iteration 30, inertia 128230.71663866629
# Iteration 31, inertia 128219.35309548117
# Iteration 32, inertia 128215.01438483749
# Iteration 33, inertia 128212.5047184811
# Iteration 34, inertia 128211.86009197096
# Converged at iteration 34: center shift 8.827141918253757e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 286680.0553767323
# Iteration 1, inertia 237228.70105534772
# Iteration 2, inertia 192385.431319998
# Iteration 3, inertia 175126.40687348222
# Iteration 4, inertia 168732.76193973434
# Iteration 5, inertia 165444.31040026655
# Iteration 6, inertia 163736.8389458966
# Iteration 7, inertia 162426.4592262265
# Iteration 8, inertia 161363.43796373575
# Iteration 9, inertia 160386.0682957688
# Iteration 10, inertia 159652.72620525138
# Iteration 11, inertia 159402.5761985574
# Iteration 12, inertia 159332.3506837517
# Iteration 13, inertia 159306.25249150782
# Iteration 14, inertia 159298.41139036888
# Converged at iteration 14: center shift 5.2570085462178e-05 within tolerance 9.99999999999928e-05.
# GridSearchCV(cv=[(slice(None, None, None), slice(None, None, None))],
#              estimator=KMeans(), n_jobs=-1,
#              param_grid={'algorithm': ['lloyd', 'elkan'], 'copy_x': [True],
#                          'init': ['random', 'k-means++'], 'max_iter': [300],
#                          'n_clusters': [5], 'n_init': [10],
#                          'random_state': [None], 'tol': [0.0001],
#                          'verbose': [1]},
#              scoring=<function cv_silhouette_scorer at 0x000001CD94A88A60>)

# %%
# %%script echo
# ls_y_pred = []
# for i in range(5):
#     model = cluster.KMeans(
#         n_clusters=5,
#         init="random",
#         n_init=10,
#         max_iter=300,
#         tol=1e-4,
#         verbose=1,
#         random_state=None,
#         copy_x=True,
#         algorithm="lloyd", # "elkan",
#     )
#     y_pred = model.fit_predict(X)
#     ls_y_pred.append(y_pred)
#     Xns["label"] = pd.Series(y_pred)
# #    print(Xns.groupby("label").R.count())
# #    print(Xns.groupby("label").mean())
# #    print(Xns.groupby("label").std())
# df_stats_ccl = pd.DataFrame(Xns.groupby("label").mean())
# df_stats_ccl.loc[:,"count"] = Xns.groupby("label").R.count()
# df_stats_ccl
# Out:
# Couldn't find program: 'echo'

# %% [markdown]
# Le KMeans trouve les clusters suivants:
# - S bas (1.6/5), RFM moyens. -> client déçu. -> Excuses et bon d'achat.
# - S haut, achat récent, FM moyens. -> nouveau client -> pas d'action.
# - S haut, achat daté, FM moyens. -> client satisfait mais perdu -> news/discount.
# - M haut, RFS moyens. -> un seul gros achat -> news.
# - F haut, RMS moyens. -> client fréquent -> proposition d'abonnement VIP.

# %%
# %%script echo
# ARIs = []
# for i, j in enumerate(ls_y_pred):
#     for m, n in enumerate(ls_y_pred):
#         ARIi = adjusted_rand_score(j, n)
# #        print(ARIi)
#         ARIs.append(ARIi)
# print(pd.Series(ARIs).mean(), pd.Series(ARIs).std())
# Out:
# Couldn't find program: 'echo'

# %% [markdown]
# >-
# # 5. Comparaison d'algorithmes

# %%
from itertools import cycle, islice
from sklearn.neighbors import kneighbors_graph

X = init_classif(df=dfrs, cols_num=["R","F","M","S"], ns=3000)

plt.figure(figsize=(21, 21))
plt.subplots_adjust(
    left=0.02, right=0.98, bottom=0.001, top=0.95, wspace=0.03, hspace=0.15
)
np.random.seed(0)

params = {
    "damping": 0.9, # .75, .9
    "eps": 3, # .2, 3
    "n_clusters": 5,
    "n_neighbors": 3, # 2, 3
    "min_cluster_size": 0.1, # .1, .2
    "min_samples": 7,
    "preference": -200, # -240, -200
    "quantile": 0.3, # .2, .3
    "xi": 0.05, # .01, .1
}

subp_dic = {
    "RF"   : [X.R, 0, X.F, 1],
    "RM"   : [X.R, 0, X.M, 2],
    "FM"   : [X.F, 1, X.M, 2],
    "RS"   : [X.R, 0, X.S, 3],
    "FS"   : [X.F, 1, X.S, 3],
    "MS"   : [X.M, 2, X.S, 3],
}

k_means = cluster.KMeans(n_clusters=params.get("n_clusters"))
spectral = cluster.SpectralClustering(
    n_clusters=params.get("n_clusters"),
    eigen_solver="arpack",
    affinity="nearest_neighbors",
)
dbscan = cluster.DBSCAN(eps=params.get("eps"))
optics = cluster.OPTICS(
    min_samples=params.get("min_samples"),
    xi=params.get("xi"),
    min_cluster_size=params.get("min_cluster_size"),
)
gmm = GaussianMixture(
    n_components=params.get("n_clusters"), covariance_type="full"
)
connectivity = kneighbors_graph(
    X, n_neighbors=params["n_neighbors"], include_self=False
)
# make connectivity symmetric
connectivity = 0.5 * (connectivity + connectivity.T)
average_linkage = cluster.AgglomerativeClustering(
    linkage="average",
    affinity="cityblock",
    n_clusters=params.get("n_clusters"),
    connectivity=connectivity,
)

clustering_algorithms = (
    ("KMeans", k_means),
    ("Spectral\nClustering", spectral),
    ("DBSCAN", dbscan),
    ("OPTICS", optics),
    ("Gaussian\nMixture", gmm),
    ("Agglomerative\nClustering", average_linkage),
)

for i_algo, (name, algorithm) in enumerate(clustering_algorithms):
    t0 = time.perf_counter()
    algorithm.fit(X)
    t1 = time.perf_counter()
    if hasattr(algorithm, "labels_"):
        y_pred = algorithm.labels_.astype(int)
    else:
        y_pred = algorithm.predict(X)
    t2 = time.perf_counter()

    colors = np.array(
        list(
            islice(
                cycle(
                    [
                        "#377eb8",
                        "#ff7f00",
                        "#4daf4a",
                        "#f781bf",
                        "#a65628",
                        "#984ea3",
                        "#999999",
                        "#e41a1c",
                        "#dede00",
                    ]
                ),
                # On re-crée colors pour chaque algo car le nombre de clusters
                # diffère.
                int(max(y_pred) + 1),
            )
        )
    )
    # add black color for outliers (if any)
    colors = np.append(colors, ["#000000"])

    for i_proj, sd in enumerate(subp_dic.values()):
        clear_output()
        print("progress: ",
              100*(1+i_proj+i_algo*len(clustering_algorithms))\
              /len(subp_dic)/len(clustering_algorithms),
              "% ", end="")

        plt.subplot(len(clustering_algorithms),
                    len(subp_dic),
                    1+i_algo+len(clustering_algorithms)*i_proj)

        plt.scatter(sd[0], sd[2], s=10, color=colors[y_pred])

        if i_proj == 0:
            plt.title(name, size=24)
        plt.xlabel(sd[0].name, size=24)
        if i_algo == 0:
            plt.ylabel(sd[2].name, size=24)
#        plt.xlim(-2.5, 2.5)
#        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
#        if i_proj == len(subp_dic)-2:
#            plt.text(
#                0.99,
#                0.01,
#                ("%.2fs" % (t1 - t0)).lstrip("0"),
#                transform=plt.gca().transAxes,
#                size=15,
#                horizontalalignment="right",
#            )
        if i_proj == len(subp_dic)-1:
            plt.text(
                0.99,
                0.01,
                ("%.2fs" % (t2 - t0)).lstrip("0"),
                transform=plt.gca().transAxes,
                size=15,
                horizontalalignment="right",
            )

plt.show()
# Out:
# progress:  100.0 %

# %%
dbscan.leaf_size
# Out:
# 30

# %%
#from scipy.cluster.hierarchy import dendrogram
#from sklearn.metrics import davies_bouldin_score
#davies_bouldin_score(X, y_pred)
