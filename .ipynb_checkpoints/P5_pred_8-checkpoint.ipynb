# %% [markdown]
# Projet 5 - Segmentez des clients d'un site e-commerce - Prediction 1
# # 1. Initialisation

# %% [markdown]
# >>-
# ## 11. Package imports

# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20, "display.max_columns", None)
import matplotlib.pyplot as plt
import seaborn as sns
#import re
import my
#import math
#import timeit
import time
#from scipy import interpolate
#import geopandas
#import os
#import sys
from IPython.display import clear_output
import warnings

# %%
from sklearn import cluster
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.metrics import silhouette_samples, silhouette_score

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>ATTENTION !</b> Tous les tests que j'ai effectués avec RobustScaler donnent une classification KMeans défaillante, qui ne tient pas du tout compte des valeurs de F. StandardScaler donne des résultats bien plus cohérents ici.</div>

# %% [markdown]
# >>-
# ## 12. Data imports

# %%
df = my.read_csv('dfs_1.csv')
dfrs = my.read_csv('dfs_rs_min.csv')
#dflog = my.read_csv('dfs_log.csv')
dfllll = my.read_csv('dfs_loglogloglog.csv')
# Out:
# Y'avait pas de colonne 'Unnamed: 0'
# Y'avait pas de colonne 'Unnamed: 0'
# Y'avait pas de colonne 'Unnamed: 0'

# %% [markdown]
# >>-
# ## 13. Initialisation des classifications

# %%
def init_classif_in(df=df, cols_num=["R","F","M"], ns=0):
    """
    Création de X à partir d'un dataset de RFM(S), éventuellement subsampled.
    """
    if "S" in cols_num:
        X = df.rename(columns={"rs": "S"})[cols_num]
    else:
        X = df[cols_num]

    if ns:
#        print(X.shape, sum(X.F == 1))
        pct = (1-sum(X.F == 1)/X.shape[0])*100
        print("Il y a {a:.1f}% de clients ayant effectué plus d'un achat "
              "dans le dataset avant subsampling.".format(a=pct))
        X = X.sample(n=ns, weights=None, random_state=1)
                     #frac=.1, weights="F", random_state=1)
#        print(X.shape, sum(X.F == 1))
        pct = (1-sum(X.F == 1)/X.shape[0])*100
        print("Il y a {a:.1f}% de clients ayant effectué plus d'un achat "
              "dans la subsample sélectionnée.".format(a=pct))

    return X

# %%
def init_classif(df=df, cols_num=["R","F","M"], ns=0):
    """
    Création de X scalé avec son propre StandardScaler.
    """
    X = init_classif_in(df, cols_num, ns)
    scaler = StandardScaler()
    X[cols_num] = scaler.fit_transform(X[cols_num])
    return X

# %% [markdown]
# >-
# # 2. Premiers tests de classification avec DBSCAN

# %% [markdown]
# >>-
# ## 21. Dataset linéaire

# %%
X = init_classif(ns=3000)
# Out:
# Il y a 2.9% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 3.0% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.

# %%
for eps in np.logspace(0,1,3):
    for mins in [1,2,3]:
        model = cluster.DBSCAN(eps=eps, min_samples=mins)
        model = model.fit(X)
        print("eps:", eps,
              ", min_samples:", mins,
              ", # labels:", len(set(model.labels_))
             )
# Out:
# eps: 1.0 , min_samples: 1 , # labels: 16
# eps: 1.0 , min_samples: 2 , # labels: 9
# eps: 1.0 , min_samples: 3 , # labels: 7
# eps: 3.1622776601683795 , min_samples: 1 , # labels: 4
# eps: 3.1622776601683795 , min_samples: 2 , # labels: 4
# eps: 3.1622776601683795 , min_samples: 3 , # labels: 4
# eps: 10.0 , min_samples: 1 , # labels: 1
# eps: 10.0 , min_samples: 2 , # labels: 1
# eps: 10.0 , min_samples: 3 , # labels: 1

# %% [markdown]
# (eps=3, min_samples=1) semble convenir.

# %%
# %%script echo
# model = cluster.DBSCAN(eps=3, min_samples=1)
# model = model.fit(X)
# y_pred = model.predict(X)
# set(model.labels_)
# Out:
# Couldn't find program: 'echo'

# %% [markdown]
# >>-
# ## 22. Dataset avec review_score

# %%
X = init_classif(df=dfrs, cols_num=["R","F","M","S"], ns=3000)
# Out:
# Il y a 2.8% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 2.8% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.

# %%
for eps in np.logspace(0,1,3):
    for mins in [1,2,3]:
        model = cluster.DBSCAN(eps=eps, min_samples=mins)
        model = model.fit(X)
        print("eps:", eps,
              ", min_samples:", mins,
              ", # labels:", len(set(model.labels_))
             )
# Out:
# eps: 1.0 , min_samples: 1 , # labels: 22
# eps: 1.0 , min_samples: 2 , # labels: 10
# eps: 1.0 , min_samples: 3 , # labels: 6
# eps: 3.1622776601683795 , min_samples: 1 , # labels: 5
# eps: 3.1622776601683795 , min_samples: 2 , # labels: 4
# eps: 3.1622776601683795 , min_samples: 3 , # labels: 4
# eps: 10.0 , min_samples: 1 , # labels: 1
# eps: 10.0 , min_samples: 2 , # labels: 1
# eps: 10.0 , min_samples: 3 , # labels: 1

# %% [markdown]
# >>-
# ## 23. Test avec min_samples grand

# %%
for eps in np.logspace(0,1,3):
    for mins in [10,30,100,300]:
        model = cluster.DBSCAN(eps=eps, min_samples=mins)
        model = model.fit(X)
        print("eps:", eps,
              ", min_samples:", mins,
              ", # labels:", len(set(model.labels_)))
# Out:
# eps: 1.0 , min_samples: 10 , # labels: 3
# eps: 1.0 , min_samples: 30 , # labels: 2
# eps: 1.0 , min_samples: 100 , # labels: 2
# eps: 1.0 , min_samples: 300 , # labels: 2
# eps: 3.1622776601683795 , min_samples: 10 , # labels: 3
# eps: 3.1622776601683795 , min_samples: 30 , # labels: 3
# eps: 3.1622776601683795 , min_samples: 100 , # labels: 2
# eps: 3.1622776601683795 , min_samples: 300 , # labels: 2
# eps: 10.0 , min_samples: 10 , # labels: 1
# eps: 10.0 , min_samples: 30 , # labels: 1
# eps: 10.0 , min_samples: 100 , # labels: 1
# eps: 10.0 , min_samples: 300 , # labels: 1

# %% [markdown]
# >>-
# ## 24. Dataset loglogloglog

# %%
X = init_classif(df=dfllll, ns=3000)
# Out:
# Il y a 2.9% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 3.0% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.

# %%
for eps in np.logspace(0,1,3):
    for mins in [1,2,3]:
        model = cluster.DBSCAN(eps=eps, min_samples=mins)
        model = model.fit(X)
        print("eps:", eps,
              ", min_samples:", mins,
              ", # labels:", len(set(model.labels_))
             )
# Out:
# eps: 1.0 , min_samples: 1 , # labels: 6
# eps: 1.0 , min_samples: 2 , # labels: 6
# eps: 1.0 , min_samples: 3 , # labels: 4
# eps: 3.1622776601683795 , min_samples: 1 , # labels: 2
# eps: 3.1622776601683795 , min_samples: 2 , # labels: 2
# eps: 3.1622776601683795 , min_samples: 3 , # labels: 2
# eps: 10.0 , min_samples: 1 , # labels: 1
# eps: 10.0 , min_samples: 2 , # labels: 1
# eps: 10.0 , min_samples: 3 , # labels: 1

# %% [markdown]
# >>-
# ## 23. Algo OPTICS

# %%
X = init_classif(ns=3000)
# Out:
# Il y a 2.9% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 3.0% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.

# %%
for mins in [.5,1,2,3]:
    model = cluster.OPTICS(min_samples=mins)
    model = model.fit(X)
    print("min_samples:", mins,
          ", # labels:", len(set(model.labels_)))
# Out:
# min_samples: 0.5 , # labels: 1
# min_samples: 1 , # labels: 1
# min_samples: 2 , # labels: 890
# min_samples: 3 , # labels: 439

# %% [markdown]
# OPTICS avec la cluster_method "xi" ne convient pas.

# %% [markdown]
# >-
# # 3. Recherche du nombre de clusters idéal pour KMeans

# %% [markdown]
# >>-
# ## 31. Dataset linéaire

# %%
X = init_classif(ns=10000)

wcss = []
range_n_clusters = range(2,7)

print("progress: ", end="")
for loop_step, n_clusters in enumerate(range_n_clusters):
    print(100*loop_step/len(range_n_clusters), "% ", end="--> ")

    y_lower = 10
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
    fig.set_size_inches(10, 3)
    plt.subplots_adjust(
        left=0.01, right=0.99, bottom=0.001, top=0.8, wspace=0.34, hspace=0.35
    )
    ax1.set_xlim([-0.07, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1)*10])
    subp_dic = {
        'RF'   : [ax2, X.R, 0, X.F, 1],
        'RM'   : [ax3, X.R, 0, X.M, 2],
        'FM'   : [ax4, X.F, 1, X.M, 2],
    }

    # We set the seed for reproducibility.
    clusterer = cluster.KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)
    centers = clusterer.cluster_centers_
    # Record wcss for the elbow graph.
    wcss.append(clusterer.inertia_)

    silhouette_avg = silhouette_score(X, cluster_labels)
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    for i in range(n_clusters):
        ith_cluster_silhouette_values = sample_silhouette_values[
            cluster_labels == i
        ]
        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            cmap="tab10",
#            cmap=sns.color_palette("bright", n_colors=n_clusters, as_cmap=True),
#            color=sns.color_palette("bright", n_colors=n_clusters),
            alpha=0.7,
        )
        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        y_lower = y_upper + 10

    ax1.set_title("Silhouettes (avg={a:1.2f})".format(a=silhouette_avg))
    ax1.set_xlabel("Silhouette coefficients")
    ax1.set_ylabel("Cluster label")
    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    for sd in subp_dic.values():
        sd[0].scatter(
            sd[1],
            sd[3],
            marker=".",
            s=30,
            lw=0,
            alpha=0.7,
            c=pd.Series(cluster_labels).map(dict(zip(np.unique(cluster_labels),
                                          sns.color_palette(
#                                              "bright",
                                              "tab10",
                                              n_colors=n_clusters,
                                          )))),
            edgecolor="k",
        )

        sd[0].scatter(
            centers[:, sd[2]],
            centers[:, sd[4]],
            marker="o",
            c="white",
            alpha=1,
            s=200,
            edgecolor="k",
        )

        for i, c in enumerate(centers):
            sd[0].scatter(
                c[sd[2]],
                c[sd[4]],
                marker="$%d$" % i,
                alpha=1,
                s=50,
                edgecolor="k",
            )

        sd[0].set_title(sd[1].name + "-" + sd[3].name + " projection")
        sd[0].set_xlabel(sd[1].name)
        sd[0].set_ylabel(sd[3].name)

    plt.suptitle(
        "KMeans Silhouette analysis for n_clusters = %d"
        % n_clusters,
        fontsize=11,
        fontweight="bold",
    )

    plt.savefig("KMeans_silhouette_RFM_" + str(n_clusters) + "clusters.png",
                bbox_inches="tight")

print(100, "%")
plt.show()

fig = plt.figure(figsize=(4, 4))
plt.plot(range_n_clusters, wcss)
plt.title("Méthode du coude")
plt.xlabel("n_clusters")
plt.ylabel("Some des carrés intra-cluster (WCSS)")
plt.savefig("KMeans_elbow_RFM_.png",
            bbox_inches="tight")
# Out:
# Il y a 2.9% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 2.7% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.
# progress: 0.0 % --> 20.0 % --> 40.0 % --> 60.0 % --> 80.0 % --> 100 %

# %% [markdown]
# La méthode du coude montre un nombre de clusters optimal de 4.
# L'analyse de silhouette donne également un nombre de clusters optimal de 4.
# Les clusters obtenus sont:
# - petit F, petit M, R_scaled > 0 (beaucoup de données)
# - petit F, petit M, R_scaled < 0 (beaucoup de données)
# - grand F, (petit M ?) (peu de données car comportement de clients plus rare)
# - (petit F ?), grand M (peu de données car comportement de clients plus rare)
# Le 5è cluster vient séparer les deux larges clusters en 3 de petit F et petit M.
# Le 6è cluster vient séparer le petit cluster de grand M en un cluster de grand M
# et un cluster de très grand M.

# %% [markdown]
# >>-
# ## 31. Dataset avec review_score

# %%
X = init_classif(df=dfrs, cols_num=["R","F","M","S"], ns=3000)

wcss = []
range_n_clusters = range(2,7)

print("progress: ", end="")
for loop_step, n_clusters in enumerate(range_n_clusters):
    print(100*loop_step/len(range_n_clusters), "% ", end="--> ")

    y_lower = 10
    fig, axs = plt.subplots(3, 4)
    fig.set_size_inches(10, 6)
    plt.subplots_adjust(
        left=0.01, right=0.99, bottom=0.001, top=0.9, wspace=0.4, hspace=0.35
    )
    axs[0,0].set_xlim([-0.07, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    axs[0,0].set_ylim([0, len(X) + (n_clusters + 1)*10])
    subp_dic = {
#        "RF"   : [axs[0,1], X.R, 0, X.F, 1, "Recency", "Frequency"],
        "RF"   : [axs[0,1], X.R, 0, X.F, 1],
        "RM"   : [axs[0,2], X.R, 0, X.M, 2],
        "FM"   : [axs[0,3], X.F, 1, X.M, 2],
        "RS"   : [axs[1,1], X.R, 0, X.S, 3],
        "FS"   : [axs[1,2], X.F, 1, X.S, 3],
        "MS"   : [axs[1,3], X.M, 2, X.S, 3],
    }

    # We set the seed for reproducibility.
    clusterer = cluster.KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)
    centers = clusterer.cluster_centers_
    # Record wcss for the elbow graph.
    wcss.append(clusterer.inertia_)

    silhouette_avg = silhouette_score(X, cluster_labels)
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    for i in range(n_clusters):
        ith_cluster_silhouette_values = sample_silhouette_values[
            cluster_labels == i
        ]
        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        axs[0,0].fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            cmap="tab10",
#            cmap=sns.color_palette("bright", n_colors=n_clusters, as_cmap=True),
#            color=sns.color_palette("bright", n_colors=n_clusters),
            alpha=0.7,
        )
        # Label the silhouette plots with their cluster numbers at the middle
        axs[0,0].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        y_lower = y_upper + 10

    axs[0,0].set_title("Silhouettes (avg={a:1.2f})".format(a=silhouette_avg))
    axs[0,0].set_xlabel("Silhouette coefficients")
    axs[0,0].set_ylabel("Cluster label")
    axs[0,0].set_yticks([])  # Clear the yaxis labels / ticks
    axs[0,0].set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    axs[0,0].axvline(x=silhouette_avg, color="red", linestyle="--")

    for sd in subp_dic.values():
        sd[0].scatter(
            sd[1],
            sd[3],
            marker=".",
            s=30,
            lw=0,
            alpha=0.7,
            c=pd.Series(cluster_labels).map(dict(zip(np.unique(cluster_labels),
                                          sns.color_palette(
#                                              "bright",
                                              "tab10",
                                              n_colors=n_clusters,
                                          )))),
            edgecolor="k",
        )

        sd[0].scatter(
            centers[:, sd[2]],
            centers[:, sd[4]],
            marker="o",
            c="white",
            alpha=1,
            s=200,
            edgecolor="k",
        )

        for i, c in enumerate(centers):
            sd[0].scatter(
                c[sd[2]],
                c[sd[4]],
                marker="$%d$" % i,
                alpha=1,
                s=50,
                edgecolor="k",
            )

        sd[0].set_title(sd[1].name + "-" + sd[3].name + " projection")
        sd[0].set_xlabel(sd[1].name)
        sd[0].set_ylabel(sd[3].name)

    subp_dic = {
        "R"   : [axs[2,0], X.R, 0],
        "F"   : [axs[2,1], X.F, 1],
        "M"   : [axs[2,2], X.M, 2],
        "S"   : [axs[2,3], X.S, 3],
    }

    for sd in subp_dic.values():
        sd[0].boxplot(sd[1])
        sd[0].set_xlabel(sd[1].name)
        #print('')

    plt.suptitle(
        "KMeans Silhouette analysis for n_clusters = %d"
        % n_clusters,
        fontsize=11,
        fontweight="bold",
    )

    axs[1,0].axis('off')

    plt.savefig("KMeans_silhouette_RFMS_" + str(n_clusters) + "clusters.png",
                bbox_inches="tight")

print(100, "%")
plt.show()

fig = plt.figure(figsize=(4, 4))
plt.plot(range_n_clusters, wcss)
plt.title("Méthode du coude")
plt.xlabel("n_clusters")
plt.ylabel("Some des carrés intra-cluster (WCSS)")
plt.savefig("KMeans_elbow_RFMS_.png",
            bbox_inches="tight")
# Out:
# Il y a 2.8% de clients ayant effectué plus d'un achat dans le dataset avant subsampling.
# Il y a 2.8% de clients ayant effectué plus d'un achat dans la subsample sélectionnée.
# progress: 0.0 % --> 20.0 % --> 40.0 % --> 60.0 % --> 80.0 % --> 100 %

# %% [markdown]
# >-
# # 4. Stabilité du KMeans à 5 clusters avec review_score

# %%
scaler = StandardScaler()
cols_num=["R","F","M","S"]
X = init_classif_in(df=dfrs, cols_num=cols_num)
Xns = X.copy()
X[cols_num] = scaler.fit_transform(X[cols_num])

# %%
ls_y_pred = []
for i in range(5):
    model = cluster.KMeans(n_clusters=5, init="random")
    y_pred = model.fit_predict(X)
    ls_y_pred.append(y_pred)
    Xns["label"] = pd.Series(y_pred)
#    print(Xns.groupby("label").R.count())
#    print(Xns.groupby("label").mean())
#    print(Xns.groupby("label").std())
df_stats_ccl = pd.DataFrame(Xns.groupby("label").mean())
df_stats_ccl.loc[:,"count"] = Xns.groupby("label").R.count()
df_stats_ccl
# Out:
#                   R         F            M         S  count
# label
# 0      1.480036e+07  1.000000   133.533519  4.668772  42116
# 1      2.529241e+07  1.000000   153.187054  1.588919  16785
# 2      2.285980e+07  2.114200   308.853573  3.723892   2662
# 3      2.473312e+07  1.019455  1279.268585  3.946498   2056
# 4      3.822627e+07  1.000000   134.891927  4.631549  31760

# %% [markdown]
# Le KMeans trouve les clusters suivants:
# - S bas (1.6/5), RFM moyens. -> client déçu. -> Excuses et bon d'achat.
# - S haut, achat récent, FM moyens. -> nouveau client -> pas d'action.
# - S haut, achat daté, FM moyens. -> client satisfait mais perdu -> news/discount.
# - M haut, RFS moyens. -> un seul gros achat -> news.
# - F haut, RMS moyens. -> client fréquent -> proposition d'abonnement VIP.

# %%
from sklearn.metrics import adjusted_rand_score

# %%
ARIs = []
for i, j in enumerate(ls_y_pred):
    for m, n in enumerate(ls_y_pred):
        ARIi = adjusted_rand_score(j, n)
#        print(ARIi)
        ARIs.append(ARIi)
print(pd.Series(ARIs).mean(), pd.Series(ARIs).std())
# Out:
# 0.8564641026271278 0.2131454587935531

# %% [markdown]
# Excellent résultat ! Le KMeans à 5 clusters trouve toujours les mêmes clusters
# malgré le init="random".

# %%
sns.scatterplot(X.R, X.M, y_pred)
# Out:
# C:\Users\achou\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='R', ylabel='M'>

# %%
scaler = StandardScaler()
cols_num=["R","F","M","S"]
X = init_classif_in(df=dfrs, cols_num=cols_num)
Xns = X.copy()
X[cols_num] = scaler.fit_transform(X[cols_num])

# %%
import sklearn
from sklearn.model_selection import GridSearchCV

def cv_silhouette_scorer(estimator, X):
    """
    Setup du scorer pour le GridSearchCV.
    Je choisis ici le silhouette_score comme scorer.
    """
    estimator.fit(X)
    cluster_labels = estimator.labels_
    num_labels = len(set(cluster_labels))
    num_samples = len(X.index)
    if num_labels == 1 or num_labels == num_samples:
        return -1
    else:
        return silhouette_score(X, cluster_labels)

param_dict = {
    "n_clusters": [5],
#    "KMeans__n_clusters": 5,
    "init": ["random", "k-means++"],
    "n_init": [10],
    "max_iter": [300],
    "tol": [1e-4],
    "verbose": [1],
    "random_state": [None],
    "copy_x": [True],
    "algorithm": ["lloyd", "elkan"],
}

cv = [(slice(None), slice(None))]
gs = GridSearchCV(estimator=sklearn.cluster.KMeans(), param_grid=param_dict,
                  scoring=cv_silhouette_scorer, cv=cv, n_jobs=-1)
gs.fit(X)
# Out:
# C:\Users\achou\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 4.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\achou\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 678, in _fit_and_score
#     estimator.fit(X_train, **fit_params)
#   File "C:\Users\achou\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py", line 1146, in fit
#     self._check_params(X)
#   File "C:\Users\achou\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py", line 956, in _check_params
#     raise ValueError(
# ValueError: Algorithm must be 'auto', 'full' or 'elkan', got lloyd instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\achou\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.41750145 0.41743997]
#   warnings.warn(
# Initialization complete
# Iteration 0, inertia 261394.71704986022
# Iteration 1, inertia 230436.58692539227
# Iteration 2, inertia 218212.80907252483
# Iteration 3, inertia 198282.7998602813
# Iteration 4, inertia 182070.4433073904
# Iteration 5, inertia 174706.9653048882
# Iteration 6, inertia 171126.00349196477
# Iteration 7, inertia 169182.68523686493
# Iteration 8, inertia 167865.87078477902
# Iteration 9, inertia 166754.41319921287
# Iteration 10, inertia 165755.20470019986
# Iteration 11, inertia 164891.8485728821
# Iteration 12, inertia 164557.09324924767
# Iteration 13, inertia 164454.05407934892
# Iteration 14, inertia 164420.588177339
# Iteration 15, inertia 164404.1651636534
# Iteration 16, inertia 164392.9944119307
# Iteration 17, inertia 164382.58107607762
# Iteration 18, inertia 164372.56562205404
# Iteration 19, inertia 164363.39911102806
# Iteration 20, inertia 164355.13820167558
# Iteration 21, inertia 164346.47375101066
# Iteration 22, inertia 164338.72542737113
# Iteration 23, inertia 164331.82865476224
# Iteration 24, inertia 164326.52084971484
# Iteration 25, inertia 164323.57633269063
# Converged at iteration 25: center shift 6.972731060265032e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 296623.4498807397
# Iteration 1, inertia 163803.36854907303
# Iteration 2, inertia 140620.06143581468
# Iteration 3, inertia 132704.60424922168
# Iteration 4, inertia 129852.00277604003
# Iteration 5, inertia 128938.87051252215
# Iteration 6, inertia 128564.7755564695
# Iteration 7, inertia 128373.46452306781
# Iteration 8, inertia 128287.80774977911
# Iteration 9, inertia 128247.14796926716
# Iteration 10, inertia 128226.17072584826
# Iteration 11, inertia 128217.79571747224
# Iteration 12, inertia 128213.65023056208
# Iteration 13, inertia 128212.06626364782
# Iteration 14, inertia 128211.48698229385
# Iteration 15, inertia 128210.90785978807
# Iteration 16, inertia 128210.45563302463
# Converged at iteration 16: center shift 3.835572499663649e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 351536.87453894253
# Iteration 1, inertia 273596.1373062662
# Iteration 2, inertia 230600.74694223035
# Iteration 3, inertia 182452.3842288009
# Iteration 4, inertia 170171.20566103153
# Iteration 5, inertia 166041.6794782296
# Iteration 6, inertia 163996.3932855896
# Iteration 7, inertia 162585.31218482353
# Iteration 8, inertia 161506.40169190225
# Iteration 9, inertia 160522.57022407363
# Iteration 10, inertia 159777.85636609333
# Iteration 11, inertia 159492.05374628183
# Iteration 12, inertia 159393.71974062434
# Iteration 13, inertia 159335.86813540672
# Iteration 14, inertia 159313.04572794386
# Iteration 15, inertia 159302.8597343847
# Iteration 16, inertia 159299.20833848984
# Converged at iteration 16: center shift 3.455698604565393e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 273085.38105053257
# Iteration 1, inertia 228208.61156512104
# Iteration 2, inertia 205557.12929108387
# Iteration 3, inertia 173921.66577200562
# Iteration 4, inertia 166681.96092661467
# Iteration 5, inertia 164341.6703715304
# Iteration 6, inertia 162991.13172576396
# Iteration 7, inertia 161848.48773225263
# Iteration 8, inertia 160896.4426885271
# Iteration 9, inertia 159946.8437734135
# Iteration 10, inertia 159498.527447371
# Iteration 11, inertia 159366.36911816962
# Iteration 12, inertia 159319.4128670739
# Iteration 13, inertia 159303.41897198855
# Iteration 14, inertia 159298.04354122566
# Converged at iteration 14: center shift 3.720830990470433e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 244265.09662546008
# Iteration 1, inertia 191064.81577683712
# Iteration 2, inertia 186008.59602784168
# Iteration 3, inertia 184277.57922295318
# Iteration 4, inertia 181624.67989283404
# Iteration 5, inertia 171613.71574455683
# Iteration 6, inertia 166111.56717210304
# Iteration 7, inertia 164131.4204751636
# Iteration 8, inertia 162877.86490152832
# Iteration 9, inertia 161790.48013000435
# Iteration 10, inertia 160813.09015793816
# Iteration 11, inertia 159899.95524687596
# Iteration 12, inertia 159507.8785302707
# Iteration 13, inertia 159391.19746213802
# Iteration 14, inertia 159334.17724534447
# Iteration 15, inertia 159309.47004621444
# Iteration 16, inertia 159300.27640819774
# Converged at iteration 16: center shift 8.296255343068557e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 275734.1639683132
# Iteration 1, inertia 222987.0563376426
# Iteration 2, inertia 196166.2952953951
# Iteration 3, inertia 179536.57891793855
# Iteration 4, inertia 172521.54319385803
# Iteration 5, inertia 169020.34091639318
# Iteration 6, inertia 166990.81852320806
# Iteration 7, inertia 165595.74348672247
# Iteration 8, inertia 164417.42324350835
# Iteration 9, inertia 163294.82768732085
# Iteration 10, inertia 162205.22447085482
# Iteration 11, inertia 161214.99405551763
# Iteration 12, inertia 159021.9273485417
# Iteration 13, inertia 154765.22696649627
# Iteration 14, inertia 146397.60323542386
# Iteration 15, inertia 132566.81605192536
# Iteration 16, inertia 129285.30237020375
# Iteration 17, inertia 128665.73850882695
# Iteration 18, inertia 128411.44319482023
# Iteration 19, inertia 128304.81871849079
# Iteration 20, inertia 128255.95387315021
# Iteration 21, inertia 128229.62517515088
# Iteration 22, inertia 128219.05599370213
# Iteration 23, inertia 128214.89219230192
# Iteration 24, inertia 128212.5054855789
# Iteration 25, inertia 128211.86158081485
# Converged at iteration 25: center shift 8.83186602185286e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 320200.999867769
# Iteration 1, inertia 244448.08100411913
# Iteration 2, inertia 204663.14953479165
# Iteration 3, inertia 175887.9618860936
# Iteration 4, inertia 130875.77160375769
# Iteration 5, inertia 129059.75139141241
# Iteration 6, inertia 128723.41338756295
# Iteration 7, inertia 128495.40960426722
# Iteration 8, inertia 128328.55502632908
# Iteration 9, inertia 128253.84157928012
# Iteration 10, inertia 128225.67091485813
# Iteration 11, inertia 128216.81963861122
# Iteration 12, inertia 128213.65216757313
# Iteration 13, inertia 128211.80409566755
# Iteration 14, inertia 128210.78504996054
# Converged at iteration 14: center shift 9.11519428890988e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 337865.7081387278
# Iteration 1, inertia 209889.38844392457
# Iteration 2, inertia 194239.0990969549
# Iteration 3, inertia 189506.46378389403
# Iteration 4, inertia 187708.49289955376
# Iteration 5, inertia 186610.17584275882
# Iteration 6, inertia 185664.80260291047
# Iteration 7, inertia 184536.87540619905
# Iteration 8, inertia 182663.3333462869
# Iteration 9, inertia 174455.94226851454
# Iteration 10, inertia 166182.30008762653
# Iteration 11, inertia 164154.1369611227
# Iteration 12, inertia 162879.74683558606
# Iteration 13, inertia 161776.7187716443
# Iteration 14, inertia 160767.34200753516
# Iteration 15, inertia 159865.51984374292
# Iteration 16, inertia 159491.32403031824
# Iteration 17, inertia 159379.3933594485
# Iteration 18, inertia 159327.59999756503
# Iteration 19, inertia 159306.3518093291
# Iteration 20, inertia 159298.8940731458
# Converged at iteration 20: center shift 5.5497118677233406e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 314313.62082394026
# Iteration 1, inertia 224714.86040189126
# Iteration 2, inertia 206087.5749578507
# Iteration 3, inertia 186807.21219086697
# Iteration 4, inertia 174059.4967493027
# Iteration 5, inertia 168081.58486973273
# Iteration 6, inertia 165116.9588512261
# Iteration 7, inertia 163540.70949326234
# Iteration 8, inertia 162250.0712624008
# Iteration 9, inertia 161103.22229367905
# Iteration 10, inertia 160039.526615637
# Iteration 11, inertia 159469.23121061135
# Iteration 12, inertia 159314.12272649785
# Iteration 13, inertia 159283.89532265224
# Iteration 14, inertia 159280.28105035514
# Converged at iteration 14: center shift 2.0503617495300823e-05 within tolerance 9.99999999999928e-05.
# Initialization complete
# Iteration 0, inertia 312881.7841176899
# Iteration 1, inertia 236204.08666261376
# Iteration 2, inertia 202011.0490671234
# Iteration 3, inertia 182404.9306396652
# Iteration 4, inertia 172942.55172744906
# Iteration 5, inertia 168655.40099586578
# Iteration 6, inertia 166359.35442749772
# Iteration 7, inertia 165013.17135506048
# Iteration 8, inertia 163855.9941195713
# Iteration 9, inertia 162913.88035495052
# Iteration 10, inertia 162086.455074034
# Iteration 11, inertia 161687.33807355913
# Iteration 12, inertia 161574.18357974742
# Iteration 13, inertia 161546.18202634936
# Iteration 14, inertia 161541.68504106128
# Converged at iteration 14: center shift 9.420780996517985e-05 within tolerance 9.99999999999928e-05.
# GridSearchCV(cv=[(slice(None, None, None), slice(None, None, None))],
#              estimator=KMeans(), n_jobs=-1,
#              param_grid={'algorithm': ['lloyd', 'elkan'], 'copy_x': [True],
#                          'init': ['random', 'k-means++'], 'max_iter': [300],
#                          'n_clusters': [5], 'n_init': [10],
#                          'random_state': [None], 'tol': [0.0001],
#                          'verbose': [1]},
#              scoring=<function cv_silhouette_scorer at 0x0000012601096430>)

# %%
# %%script echo
# ls_y_pred = []
# for i in range(5):
#     model = cluster.KMeans(
#         n_clusters=5,
#         init="random",
#         n_init=10,
#         max_iter=300,
#         tol=1e-4,
#         verbose=1,
#         random_state=None,
#         copy_x=True,
#         algorithm="lloyd", # "elkan",
#     )
#     y_pred = model.fit_predict(X)
#     ls_y_pred.append(y_pred)
#     Xns["label"] = pd.Series(y_pred)
# #    print(Xns.groupby("label").R.count())
# #    print(Xns.groupby("label").mean())
# #    print(Xns.groupby("label").std())
# df_stats_ccl = pd.DataFrame(Xns.groupby("label").mean())
# df_stats_ccl.loc[:,"count"] = Xns.groupby("label").R.count()
# df_stats_ccl
# Out:
# Couldn't find program: 'echo'

# %% [markdown]
# Le KMeans trouve les clusters suivants:
# - S bas (1.6/5), RFM moyens. -> client déçu. -> Excuses et bon d'achat.
# - S haut, achat récent, FM moyens. -> nouveau client -> pas d'action.
# - S haut, achat daté, FM moyens. -> client satisfait mais perdu -> news/discount.
# - M haut, RFS moyens. -> un seul gros achat -> news.
# - F haut, RMS moyens. -> client fréquent -> proposition d'abonnement VIP.

# %%
# %%script echo
# ARIs = []
# for i, j in enumerate(ls_y_pred):
#     for m, n in enumerate(ls_y_pred):
#         ARIi = adjusted_rand_score(j, n)
# #        print(ARIi)
#         ARIs.append(ARIi)
# print(pd.Series(ARIs).mean(), pd.Series(ARIs).std())
# Out:
# Couldn't find program: 'echo'

# %% [markdown]
# >-
# # 5. Comparaison d'algorithmes

# %%
from itertools import cycle, islice
from sklearn.neighbors import kneighbors_graph

X = init_classif(df=dfrs, cols_num=["R","F","M","S"], ns=3000)

plt.figure(figsize=(21, 21))
plt.subplots_adjust(
    left=0.02, right=0.98, bottom=0.001, top=0.95, wspace=0.03, hspace=0.15
)
np.random.seed(0)

params = {
    "damping": 0.9, # .75, .9
    "eps": 3, # .2, 3
    "n_clusters": 5,
    "n_neighbors": 3, # 2, 3
    "min_cluster_size": 0.1, # .1, .2
    "min_samples": 7,
    "preference": -200, # -240, -200
    "quantile": 0.3, # .2, .3
    "xi": 0.05, # .01, .1
}

subp_dic = {
    "RF"   : [X.R, 0, X.F, 1],
    "RM"   : [X.R, 0, X.M, 2],
    "FM"   : [X.F, 1, X.M, 2],
    "RS"   : [X.R, 0, X.S, 3],
    "FS"   : [X.F, 1, X.S, 3],
    "MS"   : [X.M, 2, X.S, 3],
}

k_means = cluster.KMeans(n_clusters=params.get("n_clusters"))
spectral = cluster.SpectralClustering(
    n_clusters=params.get("n_clusters"),
    eigen_solver="arpack",
    affinity="nearest_neighbors",
)
dbscan = cluster.DBSCAN(eps=params.get("eps"))
optics = cluster.OPTICS(
    min_samples=params.get("min_samples"),
    xi=params.get("xi"),
    min_cluster_size=params.get("min_cluster_size"),
)
gmm = GaussianMixture(
    n_components=params.get("n_clusters"), covariance_type="full"
)
connectivity = kneighbors_graph(
    X, n_neighbors=params["n_neighbors"], include_self=False
)
# make connectivity symmetric
connectivity = 0.5 * (connectivity + connectivity.T)
average_linkage = cluster.AgglomerativeClustering(
    linkage="average",
    affinity="cityblock",
    n_clusters=params.get("n_clusters"),
    connectivity=connectivity,
)

clustering_algorithms = (
    ("KMeans", k_means),
    ("Spectral\nClustering", spectral),
    ("DBSCAN", dbscan),
    ("OPTICS", optics),
    ("Gaussian\nMixture", gmm),
    ("Agglomerative\nClustering", average_linkage),
)

for i_algo, (name, algorithm) in enumerate(clustering_algorithms):
    t0 = time.perf_counter()
    algorithm.fit(X)
    t1 = time.perf_counter()
    if hasattr(algorithm, "labels_"):
        y_pred = algorithm.labels_.astype(int)
    else:
        y_pred = algorithm.predict(X)
    t2 = time.perf_counter()

    colors = np.array(
        list(
            islice(
                cycle(
                    [
                        "#377eb8",
                        "#ff7f00",
                        "#4daf4a",
                        "#f781bf",
                        "#a65628",
                        "#984ea3",
                        "#999999",
                        "#e41a1c",
                        "#dede00",
                    ]
                ),
                # On re-crée colors pour chaque algo car le nombre de clusters
                # diffère.
                int(max(y_pred) + 1),
            )
        )
    )
    # add black color for outliers (if any)
    colors = np.append(colors, ["#000000"])

    for i_proj, sd in enumerate(subp_dic.values()):
        clear_output()
        print("progress: ",
              100*(1+i_proj+i_algo*len(clustering_algorithms))\
              /len(subp_dic)/len(clustering_algorithms),
              "% ", end="")

        plt.subplot(len(clustering_algorithms),
                    len(subp_dic),
                    1+i_algo+len(clustering_algorithms)*i_proj)

        plt.scatter(sd[0], sd[2], s=10, color=colors[y_pred])

        if i_proj == 0:
            plt.title(name, size=24)
        plt.xlabel(sd[0].name, size=24)
        if i_algo == 0:
            plt.ylabel(sd[2].name, size=24)
#        plt.xlim(-2.5, 2.5)
#        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
#        if i_proj == len(subp_dic)-2:
#            plt.text(
#                0.99,
#                0.01,
#                ("%.2fs" % (t1 - t0)).lstrip("0"),
#                transform=plt.gca().transAxes,
#                size=15,
#                horizontalalignment="right",
#            )
        if i_proj == len(subp_dic)-1:
            plt.text(
                0.99,
                0.01,
                ("%.2fs" % (t2 - t0)).lstrip("0"),
                transform=plt.gca().transAxes,
                size=15,
                horizontalalignment="right",
            )

plt.show()
# Out:
# progress:  100.0 %

# %%
dbscan.leaf_size
# Out:
# 30

# %%
#from scipy.cluster.hierarchy import dendrogram
#from sklearn.metrics import davies_bouldin_score
#davies_bouldin_score(X, y_pred)
